# %% [markdown]
# Importação das Bibliotecas

# %%
import numpy as np
import pandas as pd
import json
import folium

# !python -m pip install pymongo
from pymongo import MongoClient
# Out:
# Collecting pymongo
#   Downloading pymongo-4.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Downloading pymongo-4.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 17.2 MB/s eta 0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 16.8 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.7.0 pymongo-4.10.1

# %% [markdown]
# Dataset contendo dados dos estádios

# %%
dataset = "https://raw.githubusercontent.com/ProfAndersonVanin/FATEC_BDNAORELACIONAL_2SEM2024/refs/heads/main/Coordenadas%20csv.csv"

# %% [markdown]
# Conversão em DATAFRAME PANDA

# %%
estadio_df = pd.read_csv(dataset)

# %% [markdown]
# Visualizando os 5 primeiros registros do DataFrame

# %%
# Load the necessary library.
import pandas as pd

# Define the dataset URL.
dataset = "https://raw.githubusercontent.com/ProfAndersonVanin/FATEC_BDNAORELACIONAL_2SEM2024/refs/heads/main/Coordenadas%20csv.csv"

# Read the CSV file into a Pandas DataFrame, ensuring consistent variable naming.
estadios_df = pd.read_csv(dataset)  # Changed variable name to 'estadios_df'

# Display the first 5 rows of the DataFrame.
estadios_df.head(5)  # Use the correct variable name 'estadios_df'
# Out:
#              nome  capacidade  latitude  longitude
# 0        Maracanã       78838 -22.90981  -43.23391
# 1  Mané Garrincha       72000 -15.78375  -47.89903
# 2         Morumbi       66795 -23.60006  -46.72016
# 3  Arena Castelão       63903  -3.80674  -38.52168
# 4        Mineirão       61927 -19.86591  -43.97104

# %% [markdown]
# Convertendo o DataFrame em um dicionário (arquivo parecido com um JSON)

# %%
dicionario_estadios = estadios_df.to_dict(orient='records')

# %% [markdown]
# visualizando o dicionario...

# %%
dicionario_estadios
# Out:
# [{'nome': 'Maracanã',
#   'capacidade': 78838,
#   'latitude': -22.90981,
#   'longitude': -43.23391},
#  {'nome': 'Mané Garrincha',
#   'capacidade': 72000,
#   'latitude': -15.78375,
#   'longitude': -47.89903},
#  {'nome': 'Morumbi',
#   'capacidade': 66795,
#   'latitude': -23.60006,
#   'longitude': -46.72016},
#  {'nome': 'Arena Castelão',
#   'capacidade': 63903,
#   'latitude': -3.80674,
#   'longitude': -38.52168},
#  {'nome': 'Mineirão',
#   'capacidade': 61927,
#   'latitude': -19.86591,
#   'longitude': -43.97104},
#  {'nome': 'Arruda',
#   'capacidade': 60000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'nome': 'Arena do Grêmio',
#   'capacidade': 55662,
#   'latitude': -29.97404,
#   'longitude': -51.19511},
#  {'nome': 'Mangueirão',
#   'capacidade': 55645,
#   'latitude': -1.38114,
#   'longitude': -48.44483},
#  {'nome': 'Beira-Rio',
#   'capacidade': 50848,
#   'latitude': -30.06549,
#   'longitude': -51.23492},
#  {'nome': 'Neo Química Arena',
#   'capacidade': 48234,
#   'latitude': -23.54529,
#   'longitude': -46.47429},
#  {'nome': 'Arena Fonte Nova',
#   'capacidade': 48000,
#   'latitude': -12.97889,
#   'longitude': -38.50348},
#  {'nome': 'Parque do Sabiá',
#   'capacidade': 46782,
#   'latitude': -18.91309,
#   'longitude': -48.23299},
#  {'nome': 'Arena Pernambuco',
#   'capacidade': 46000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'nome': 'Arena MRV',
#   'capacidade': 46000,
#   'latitude': -19.93001,
#   'longitude': -44.01388},
#  {'nome': 'Prudentão',
#   'capacidade': 45954,
#   'latitude': -22.09857,
#   'longitude': -51.41506},
#  {'nome': 'Engenhão',
#   'capacidade': 45217,
#   'latitude': -22.89319,
#   'longitude': -43.29357},
#  {'nome': 'Albertão',
#   'capacidade': 44200,
#   'latitude': -5.11614,
#   'longitude': -42.79287},
#  {'nome': 'Morenão',
#   'capacidade': 44200,
#   'latitude': -20.50143,
#   'longitude': -54.61022},
#  {'nome': 'Arena Pantanal',
#   'capacidade': 44097,
#   'latitude': -15.60406,
#   'longitude': -56.1223},
#  {'nome': 'Arena da Amazônia',
#   'capacidade': 44000,
#   'latitude': -3.08434,
#   'longitude': -60.0265}]

# %%
cliente = MongoClient("mongodb+srv://lordrojas7:WUEywYhbEix291wB@clusterestadios.lvuzg.mongodb.net/?retryWrites=true&w=majority&appName=ClusterEstadios")

# %%
db = cliente.get_database('futebol')

# %%
db.estadios.insert_many(dicionario_estadios)
# Out:
# InsertManyResult([ObjectId('6718323527b090f2a4bfccbb'), ObjectId('6718323527b090f2a4bfccbc'), ObjectId('6718323527b090f2a4bfccbd'), ObjectId('6718323527b090f2a4bfccbe'), ObjectId('6718323527b090f2a4bfccbf'), ObjectId('6718323527b090f2a4bfccc0'), ObjectId('6718323527b090f2a4bfccc1'), ObjectId('6718323527b090f2a4bfccc2'), ObjectId('6718323527b090f2a4bfccc3'), ObjectId('6718323527b090f2a4bfccc4'), ObjectId('6718323527b090f2a4bfccc5'), ObjectId('6718323527b090f2a4bfccc6'), ObjectId('6718323527b090f2a4bfccc7'), ObjectId('6718323527b090f2a4bfccc8'), ObjectId('6718323527b090f2a4bfccc9'), ObjectId('6718323527b090f2a4bfccca'), ObjectId('6718323527b090f2a4bfcccb'), ObjectId('6718323527b090f2a4bfcccc'), ObjectId('6718323527b090f2a4bfcccd'), ObjectId('6718323527b090f2a4bfccce')], acknowledged=True)

# %%
estadios = db.estadios

# %%
estadios
# Out:
# Collection(Database(MongoClient(host=['clusterestadios-shard-00-00.lvuzg.mongodb.net:27017', 'clusterestadios-shard-00-02.lvuzg.mongodb.net:27017', 'clusterestadios-shard-00-01.lvuzg.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='ClusterEstadios', authsource='admin', replicaset='atlas-uzvm9f-shard-0', tls=True), 'futebol'), 'estadios')

# %%
list(estadios.find())
# Out:
# [{'_id': ObjectId('671831e070ca5b6a63b4df6a'),
#   'nome': 'Vila Belmiro',
#   'capacidade': 21732,
#   'latitude': -23.57243,
#   'longitude': -46.20123},
#  {'_id': ObjectId('6718323527b090f2a4bfccbb'),
#   'nome': 'Maracanã',
#   'capacidade': 78838,
#   'latitude': -22.90981,
#   'longitude': -43.23391},
#  {'_id': ObjectId('6718323527b090f2a4bfccbc'),
#   'nome': 'Mané Garrincha',
#   'capacidade': 72000,
#   'latitude': -15.78375,
#   'longitude': -47.89903},
#  {'_id': ObjectId('6718323527b090f2a4bfccbd'),
#   'nome': 'Morumbi',
#   'capacidade': 66795,
#   'latitude': -23.60006,
#   'longitude': -46.72016},
#  {'_id': ObjectId('6718323527b090f2a4bfccbe'),
#   'nome': 'Arena Castelão',
#   'capacidade': 63903,
#   'latitude': -3.80674,
#   'longitude': -38.52168},
#  {'_id': ObjectId('6718323527b090f2a4bfccbf'),
#   'nome': 'Mineirão',
#   'capacidade': 61927,
#   'latitude': -19.86591,
#   'longitude': -43.97104},
#  {'_id': ObjectId('6718323527b090f2a4bfccc0'),
#   'nome': 'Arruda',
#   'capacidade': 60000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'_id': ObjectId('6718323527b090f2a4bfccc1'),
#   'nome': 'Arena do Grêmio',
#   'capacidade': 55662,
#   'latitude': -29.97404,
#   'longitude': -51.19511},
#  {'_id': ObjectId('6718323527b090f2a4bfccc2'),
#   'nome': 'Mangueirão',
#   'capacidade': 55645,
#   'latitude': -1.38114,
#   'longitude': -48.44483},
#  {'_id': ObjectId('6718323527b090f2a4bfccc3'),
#   'nome': 'Beira-Rio',
#   'capacidade': 50848,
#   'latitude': -30.06549,
#   'longitude': -51.23492},
#  {'_id': ObjectId('6718323527b090f2a4bfccc4'),
#   'nome': 'Neo Química Arena',
#   'capacidade': 48234,
#   'latitude': -23.54529,
#   'longitude': -46.47429},
#  {'_id': ObjectId('6718323527b090f2a4bfccc5'),
#   'nome': 'Arena Fonte Nova',
#   'capacidade': 48000,
#   'latitude': -12.97889,
#   'longitude': -38.50348},
#  {'_id': ObjectId('6718323527b090f2a4bfccc6'),
#   'nome': 'Parque do Sabiá',
#   'capacidade': 46782,
#   'latitude': -18.91309,
#   'longitude': -48.23299},
#  {'_id': ObjectId('6718323527b090f2a4bfccc7'),
#   'nome': 'Arena Pernambuco',
#   'capacidade': 46000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'_id': ObjectId('6718323527b090f2a4bfccc8'),
#   'nome': 'Arena MRV',
#   'capacidade': 46000,
#   'latitude': -19.93001,
#   'longitude': -44.01388},
#  {'_id': ObjectId('6718323527b090f2a4bfccc9'),
#   'nome': 'Prudentão',
#   'capacidade': 45954,
#   'latitude': -22.09857,
#   'longitude': -51.41506},
#  {'_id': ObjectId('6718323527b090f2a4bfccca'),
#   'nome': 'Engenhão',
#   'capacidade': 45217,
#   'latitude': -22.89319,
#   'longitude': -43.29357},
#  {'_id': ObjectId('6718323527b090f2a4bfcccb'),
#   'nome': 'Albertão',
#   'capacidade': 44200,
#   'latitude': -5.11614,
#   'longitude': -42.79287},
#  {'_id': ObjectId('6718323527b090f2a4bfcccc'),
#   'nome': 'Morenão',
#   'capacidade': 44200,
#   'latitude': -20.50143,
#   'longitude': -54.61022},
#  {'_id': ObjectId('6718323527b090f2a4bfcccd'),
#   'nome': 'Arena Pantanal',
#   'capacidade': 44097,
#   'latitude': -15.60406,
#   'longitude': -56.1223},
#  {'_id': ObjectId('6718323527b090f2a4bfccce'),
#   'nome': 'Arena da Amazônia',
#   'capacidade': 44000,
#   'latitude': -3.08434,
#   'longitude': -60.0265}]

# %%
#definindo o centro do brasil
center_lat = -12.24007
center_lon = -51.18050

# %%
consulta = list(estadios.find())

# %%
df_convertido = pd.DataFrame(consulta)

# %%
df_convertido.iloc[0]
# Out:
# _id           671831e070ca5b6a63b4df6a
# nome                      Vila Belmiro
# capacidade                       21732
# latitude                     -23.57243
# longitude                    -46.20123
# Name: 0, dtype: object

# %%
locationmap = folium.Map(location=[center_lat, center_lon], zoom_start=5, width=800, height=600)

# %%
qtde = len(df_convertido)

# %%
for i in range(qtde):
    lat = df_convertido.iloc[i]['latitude']
    lon = df_convertido.iloc[i]['longitude']
    description = 'Estadio:' + str(df_convertido.iloc[i]['nome']) + '<br> Capacidade:' + str(df_convertido.iloc[i]['capacidade'])
    folium.Marker([lat, lon],
                  popup=description, icon=folium.Icon(color='green')).add_to(locationmap)

# %%
locationmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_923eee9298233b3c5fe3dd007eb1b838 {
#                     position: relative;
#                     width: 800.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_923eee9298233b3c5fe3dd007eb1b838&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_923eee9298233b3c5fe3dd007eb1b838 = L.map(
#                 &quot;map_923eee9298233b3c5fe3dd007eb1b838&quot;,
#                 {
#                     center: [-14.24007, -53.1805],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b27efdb9b5473653072ae705d8134199 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b27efdb9b5473653072ae705d8134199.addTo(map_923eee9298233b3c5fe3dd007eb1b838);
#
#
#             var marker_7596b9a4626e6024dba520487472e703 = L.marker(
#                 [-46.20123, -23.57243],
#                 {}
#             ).addTo(map_923eee9298233b3c5fe3dd007eb1b838);
#
#
#             var icon_c5c9bc05a39d9d0c50c1e061784d831c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7596b9a4626e6024dba520487472e703.setIcon(icon_c5c9bc05a39d9d0c50c1e061784d831c);
#
#
#         var popup_ba58ee97a2e66fbee4d5051795dc2e24 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_44da11f49550abf83b83ba35cc6f39b8 = $(`&lt;div id=&quot;html_44da11f49550abf83b83ba35cc6f39b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estadio:Vila Belmiro&lt;br&gt; Capacidade:21732&lt;/div&gt;`)[0];
#                 popup_ba58ee97a2e66fbee4d5051795dc2e24.setContent(html_44da11f49550abf83b83ba35cc6f39b8);
#
#
#
#         marker_7596b9a4626e6024dba520487472e703.bindPopup(popup_ba58ee97a2e66fbee4d5051795dc2e24)
#         ;
#
#
#
#
#             var marker_2d8e99acbf3df1a5a28dcd2cf8b5fa1c = L.marker(
#                 [-43.23391, -22.90981],
#                 {}
#             ).addTo(map_923eee9298233b3c5fe3dd007eb1b838);
#
#
#             var icon_e1f2aa56d75d9122b0dd1c88a26b47a9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2d8e99acbf3df1a5a28dcd2cf8b5fa1c.setIcon(icon_e1f2aa56d75d9122b0dd1c88a26b47a9);
#
#
#         var popup_3f0679632eadb20a01c8a491dcc01214 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3d333dea4e4be580e553872bccea5072 = $(`&lt;div id=&quot;html_3d333dea4e4be580e553872bccea5072&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estadio:Maracanã&lt;br&gt; Capacidade:78838&lt;/div&gt;`)[0];
#                 popup_3f0679632eadb20a01c8a491dcc01214.setContent(html_3d333dea4e4be580e553872bccea5072);
#
#
#
#         marker_2d8e99acbf3df1a5a28dcd2cf8b5fa1c.bindPopup(popup_3f0679632eadb20a01c8a491dcc01214)
#         ;
#
#
#
#
#             var marker_673e554df2a0231d4b962456ab569918 = L.marker(
#                 [-47.89903, -15.78375],
#                 {}
#             ).addTo(map_923eee9298233b3c5fe3dd007eb1b838);
#
#
#             var icon_17ef00f07419dffc098f67edcafebe38 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_673e554df2a0231d4b962456ab569918.setIcon(icon_17ef00f07419dffc098f67edcafebe38);
#
#
#         var popup_bfe673f9126b5c5729b24c30c61f553f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5abbdf75d3513fa1f72b68166ff3977a = $(`&lt;div id=&quot;html_5abbdf75d3513fa1f72b68166ff3977a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estadio:Mané Garrincha&lt;br&gt; Capacidade:72000&lt;/div&gt;`)[0];
#                 popup_bfe673f9126b5c5729b24c30c61f553f.setContent(html_5abbdf75d3513fa1f72b68166ff3977a);
#
#
#
#         marker_673e554df2a0231d4b962456ab569918.bindPopup(popup_bfe673f9126b5c5729b24c30c61f553f)
#         ;
#
#
#
#
#             var marker_d246bc06eba52e9cf5f95395c039cf1e = L.marker(
#                 [-46.72016, -23.60006],
#                 {}
#             ).addTo(map_923eee9298233b3c5fe3dd007eb1b838);
#
#
#             var icon_f7ced53f0eee0afaa9c7a0c1fc958b57 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-
